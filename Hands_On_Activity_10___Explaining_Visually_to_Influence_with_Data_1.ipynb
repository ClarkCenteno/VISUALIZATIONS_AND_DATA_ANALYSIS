# %% [markdown]
# <a href="https://colab.research.google.com/github/ClarkCenteno/VISUALIZATIONS_AND_DATA_ANALYSIS/blob/main/Hands_On_Activity_10___Explaining_Visually_to_Influence_with_Data_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Hands-On Activity 10 | Explaining Visually to Influence with Data**
#
#
#
#
#
# ---

# %% [markdown]
# Name : Clark Kent B. Centeno<br>
# Course Code and Title : CPE 031  Visualization and Data Analysis<br>
# Date Submitted : October 30, 2025<br>
# Instructor : Engr. Maria Rizette Sayo
#
#
# ---

# %% [markdown]
# **1. Objectives:**
#
# This activity aims to help students demonstrate how to influence and communicate effectively with data by identifying audience needs, crafting a clear message, and telling a story visually through charts.

# %% [markdown]
# **2. Intended Learning Outcomes (ILOs):**
#
# By the end of this activity, students should be able to:
#
# 1. Analyze the audience to understand their level of data knowledge and needs.
#
# 2. Evaluate how well a message and visualization communicate insights.
#
# 3. Create a clear and meaningful data story using Python visualization tools.

# %% [markdown]
# **3. Discussions:**
#
# Data storytelling goes beyond showing charts it’s about influencing decisions and sparking understanding.
#
# Know Your Audience: Decision-makers may prefer clear summaries, while analysts like detailed data.
#
# Know Your Message: Focus on the why it matters part of the story.
#
# Tell a Story: Use preattentive attributes color, size, and position to guide attention.
#
# Structure Your Story: Like Aristotle’s rhetorical triangle, combine logic (logos), emotion (pathos), and credibility (ethos).

# %% [markdown]
# **4. Procedures:**

# %% [markdown]
# Step 1. Import Libraries and Create Sample Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample sales dataset
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Sales": [200, 250, 180, 300, 280, 350],
    "Marketing_Spend": [50, 60, 45, 70, 65, 80]
}
df = pd.DataFrame(data)
df
# Out:
#   Month  Sales  Marketing_Spend
# 0   Jan    200               50
# 1   Feb    250               60
# 2   Mar    180               45
# 3   Apr    300               70
# 4   May    280               65
# 5   Jun    350               80

# %% [markdown]
# Step 2. Know Your Audience — Compare Chart Styles

# %%
# Executive audience: prefer clarity (simple bar)
plt.figure(figsize=(7,4))
sns.barplot(x="Month", y="Sales", data=df, color="steelblue")
plt.title("Executive View: Monthly Sales Overview", fontsize=13)
plt.show()

# Analyst audience: prefer detailed trends (line chart)
plt.figure(figsize=(7,4))
sns.lineplot(x="Month", y="Sales", data=df, marker="o", label="Sales")
sns.lineplot(x="Month", y="Marketing_Spend", data=df, marker="o", label="Marketing Spend")
plt.title("Analyst View: Sales vs Marketing Trend", fontsize=13)
plt.legend()
plt.show()

# %% [markdown]
# **Task 1:** Create one additional visualization suited for a different audience (e.g., a customer, investor, or teammate).

# %%
#customers perspective: prefers simple yet straight to the point trends
plt.figure(figsize=(7,4))
sns.lineplot(x="Month", y="Sales", data=df, marker="o", label="Sales")
plt.title("Customer View: Sales", fontsize=13)
plt.legend()
plt.show()

# %% [markdown]
# Step 3. Know Your Message — Highlight What Matters

# %%
# Highlight the highest sales month (preattentive color cue)
highlight = df["Sales"].idxmax()

colors = ["gray" if i != highlight else "crimson" for i in range(len(df))]
plt.figure(figsize=(7,4))
plt.bar(df["Month"], df["Sales"], color=colors)
plt.title("Highlighting the Best Month in Sales", fontsize=13)
plt.show()

# %% [markdown]
# **Task 2:** Use color or annotations to emphasize a key insight (e.g., lowest point, sudden increase).

# %%
highlight = df["Marketing_Spend"].idxmin()

colors = ["brown" if i != highlight else "lightyellow" for i in range(len(df))]
plt.figure(figsize=(7,4))
plt.bar(df["Month"], df["Marketing_Spend"], color=colors)
plt.title("Highlighting the Least Marketing Spent", fontsize=13)
plt.show()

# %% [markdown]
# Step 4. Storytelling with Charts — Beginning, Middle, End

# %%
# Beginning: Context
plt.figure(figsize=(7,4))
sns.barplot(x="Month", y="Sales", data=df, color="skyblue")
plt.title("Beginning: Sales Started Steady", fontsize=13)
plt.show()

# Middle: Change or Challenge
plt.figure(figsize=(7,4))
sns.lineplot(x="Month", y="Sales", data=df, color="orange", marker="o")
plt.title("Middle: A Drop in March Due to Low Marketing", fontsize=13)
plt.show()

# End: Resolution
plt.figure(figsize=(7,4))
sns.barplot(x="Month", y="Sales", data=df, color="limegreen")
plt.title("End: Recovery and Growth After March", fontsize=13)
plt.show()

# %% [markdown]
# **Task 3:** Write one or two lines describing your data story from beginning → middle → end.

# %% [markdown]
# As the month started, the sales were steady. As March appeared, the sales dropped tremendously. After the sudden drop in March, the sales skyrocketed.

# %% [markdown]
# Step 5. Bringing It All Together — Presentation Design

# %%
# Simple combined story chart
plt.figure(figsize=(8,5))
sns.lineplot(x="Month", y="Sales", data=df, marker="o", linewidth=2, color="royalblue", label="Sales")
sns.lineplot(x="Month", y="Marketing_Spend", data=df, marker="o", linestyle="--", color="green", label="Marketing Spend")

plt.fill_between(df["Month"], df["Sales"], alpha=0.1, color="royalblue")
plt.title("From Effort to Impact: Marketing Spend Drives Sales Growth", fontsize=13)
plt.legend()
plt.show()

# %% [markdown]
# ---
#
#
# **5. Supplementary Activity:**

# %% [markdown]
# 1. Use a small dataset available online (kaggle, google dataset, etc.).
#
# 2. Visualize it using a bar chart.
#
# 3. Highlight one important data point (e.g., the highest or lowest value) using a distinct color.
#
# 4. Add a title and annotation that tell the story behind the data.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/CPE 031_CENTENO/youtube-top-100-songs-2025.csv")

# %%
df
# Out:
#                                                 title  \
# 0    ROSÉ & Bruno Mars - APT. (Official Music Video)
# 1   Lady Gaga, Bruno Mars - Die With A Smile (Offi...
# 2   Reneé Rapp - Leave Me Alone (Official Music Vi...
# 3   Billie Eilish - BIRDS OF A FEATHER (Official M...
# 4             Reneé Rapp - Mad (Official Music Video)
# ..                                                ...
# 95  Ariana Grande - twilight zone (Official Lyric ...
# 96  Gracie Abrams - I Love You, I’m Sorry (Officia...
# 97  HoodTrophy Bino ft. FCG Heem - Miami (Official...
# 98               Sean Paul x INNA - Let It Talk To Me
# 99  Selena Gomez, benny blanco - How Does It Feel ...
#
#                                             fulltitle  \
# 0    ROSÉ & Bruno Mars - APT. (Official Music Video)
# 1   Lady Gaga, Bruno Mars - Die With A Smile (Offi...
# 2   Reneé Rapp - Leave Me Alone (Official Music Vi...
# 3   Billie Eilish - BIRDS OF A FEATHER (Official M...
# 4             Reneé Rapp - Mad (Official Music Video)
# ..                                                ...
# 95  Ariana Grande - twilight zone (Official Lyric ...
# 96  Gracie Abrams - I Love You, I’m Sorry (Officia...
# 97  HoodTrophy Bino ft. FCG Heem - Miami (Official...
# 98               Sean Paul x INNA - Let It Talk To Me
# 99  Selena Gomez, benny blanco - How Does It Feel ...
#
#                                           description  view_count categories  \
# 0   ROSÉ & Bruno Mars - APT.\nDownload/stream: ht...  2009014557      Music
# 1   MAYHEM OUT NOW\nhttp://ladygaga.com \n \nListe...  1324833300      Music
# 2   Listen to “BITE ME”, the new album from Reneé ...     2536628      Music
# 3   Listen to HIT ME HARD AND SOFT: https://billie...   558329099      Music
# 4   Listen to “BITE ME”, the new album from Reneé ...     2113548      Music
# ..                                                ...         ...        ...
# 95  The official “twilight zone” official lyric vi...    18245315      Music
# 96  Listen to the new album, The Secret of Us, out...    31456772      Music
# 97  HoodTrophy Bino and FCG Heem drop Miami.  From...       66051      Music
# 98  Song Title: Sean Paul x INNA - Let It Talk To ...    16952860      Music
# 99  Listen to the new album 'I Said I Love You Fir...    16971256      Music
#
#                                                  tags  duration  \
# 0   YG Entertainment;YG;와이지;K-pop;BLACKPINK;블랙핑크;블...       173
# 1                 Lady Gaga;Bruno Mars;Interscope;Pop       252
# 2                   Reneé Rapp;Interscope Records;Pop       160
# 3   Billie Eilish;Darkroom/Interscope Records;Alte...       231
# 4                   Reneé Rapp;Interscope Records;Pop       180
# ..                                                ...       ...
# 95                 Ariana Grande;Republic Records;Pop       202
# 96  Gracie Abrams;Gracie Abrams, under exclusive l...       234
# 97                                                NaN       197
# 98                                          Sean Paul       155
# 99  Selena Gomez;benny blanco;SMG Music LLC Friend...       161
#
#    duration_string  live_status  \
# 0             2:53        False
# 1             4:12        False
# 2             2:40        False
# 3             3:51        False
# 4             3:00        False
# ..             ...          ...
# 95            3:22        False
# 96            3:54        False
# 97            3:17        False
# 98            2:35        False
# 99            2:41        False
#
#                                             thumbnail          channel  \
# 0   https://i.ytimg.com/vi_webp/ekr2nIex040/maxres...             ROSÉ
# 1   https://i.ytimg.com/vi/kPa7bsKwL-c/maxresdefau...        Lady Gaga
# 2   https://i.ytimg.com/vi/tiPWzFLiz4A/maxresdefau...       Reneé Rapp
# 3   https://i.ytimg.com/vi/V9PVRfjEBTI/maxresdefau...    Billie Eilish
# 4   https://i.ytimg.com/vi/xkWQM3flsiY/maxresdefau...       Reneé Rapp
# ..                                                ...              ...
# 95  https://i.ytimg.com/vi/x1XIJM6spaE/maxresdefau...    Ariana Grande
# 96  https://i.ytimg.com/vi/uxjhN_Donfw/maxresdefau...    Gracie Abrams
# 97  https://i.ytimg.com/vi_webp/I-gmbHgeN1I/maxres...  HoodTrophy Bino
# 98  https://i.ytimg.com/vi_webp/nkRyAVQdqAA/maxres...        Sean Paul
# 99  https://i.ytimg.com/vi/4LcNr0T2yAA/maxresdefau...     Selena Gomez
#
#                                           channel_url  channel_follower_count
# 0   https://www.youtube.com/channel/UCBo1hnzxV9rz3...                19200000
# 1   https://www.youtube.com/channel/UC07Kxew-cMIay...                29600000
# 2   https://www.youtube.com/channel/UCZy4ki_L4bzw9...                  408000
# 3   https://www.youtube.com/channel/UCDGmojLIoWpXo...                56800000
# 4   https://www.youtube.com/channel/UCZy4ki_L4bzw9...                  408000
# ..                                                ...                     ...
# 95  https://www.youtube.com/channel/UC0VOyT2OCBKdQ...                56400000
# 96  https://www.youtube.com/channel/UCVFRVXH1hRoWk...                 1770000
# 97  https://www.youtube.com/channel/UCsaZi3QZrZ5-s...                   20300
# 98  https://www.youtube.com/channel/UCkdc7gHpavxpg...                 5200000
# 99  https://www.youtube.com/channel/UCjK8ORC71kwyj...                35500000
#
# [100 rows x 13 columns]

# %%
highlight = df["view_count"].idxmax()

colors = ["crimson" if i != highlight else "lightblue" for i in range(len(df))]
plt.figure(figsize=(25,12))
plt.bar(df["title"], df["view_count"], color=colors)
plt.title("Youtube TOP 100 music of 2025", fontsize=13)
plt.xticks(rotation=90, ha='right', fontsize=8) # Rotate labels and adjust font size
plt.xlabel('') # Remove x-axis label as titles are self-explanatory
plt.ylabel('View Count') # Add y-axis label
plt.tight_layout() # Adjust layout to prevent labels from being cut off
plt.show()
print("This bar graph shows the top 100 music videos in 2025 in youtube.com, this shows that APT by Rose and Bruno Mars clinched the top 1 spot on this list, \nthis proves that APT is by far the most popular youtube music video in 2025")
# Out:
# This bar graph shows the top 100 music videos in 2025 in youtube.com, this shows that APT by Rose and Bruno Mars clinched the top 1 spot on this list,
# this proves that APT is by far the most popular youtube music video in 2025

# %% [markdown]
# **6. Conclusion/Learnings/Analysis:**

# %% [markdown]
# This hand on activity taught me that visualization is very important when it comes to presenting stories or by simply story telling beause it tells the idea clearly and more refined than having bad visualization, different graphs and charts using colors and legends helps out with the overall presentation and how the graph is being presented using visual aids.
